# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in /Users/olgaromanova/anaconda3/lib/python3.7/site-packages (0.0)
# ...
# WARNING: You are using pip version 19.3.1; however, version 20.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# ...
# WARNING: You are using pip version 19.3.1; however, version 20.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df.columns
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
#        'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
#        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
#        'koi_kepmag'],
#       dtype='object')

# %%
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1     ...      koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
#selected_features = df[['names', 'of', 'selected', 'features', 'here']]
y=df['koi_disposition']
X=df.drop(['koi_disposition'],axis=1)
X.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2     ...      koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
# 6370              0              1              0              1    0.733726
# 2879              1              0              0              0    7.652707
# 107               0              0              0              0    7.953547
# 29                0              0              0              0    4.959319
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6122     7.380000e-05    -7.380000e-05   133.077240          0.008440
# 6370     6.060000e-06    -6.060000e-06   132.020050          0.007950
# 2879     6.540000e-05    -6.540000e-05   134.460380          0.006190
# 107      1.910000e-05    -1.910000e-05   174.662240          0.001820
# 29       5.150000e-07    -5.150000e-07   172.258529          0.000083
#
#       koi_time0bk_err2     ...      koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# # Scaling X and y

# %%
# Scale your data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
X_scaler=MinMaxScaler().fit(X_train)
X_train_sc=X_scaler.transform(X_train)
X_test_sc=X_scaler.transform(X_test)

y_encoder=LabelEncoder().fit(y_train)
y_train_encod=y_encoder.transform(y_train)
y_test_encod=y_encoder.transform(y_test)

from keras.utils import to_categorical
y_train_cat=to_categorical(y_train_encod)
y_test_cat=to_categorical(y_test_encod)

# %% [markdown]
# # Deep Keras Model -the Best Model

# %%
from keras.models import Sequential
from keras.layers import Dense
model=Sequential()
number_inputs=40
number_output=3
nodes_number=100
model.add(Dense(units=nodes_number, activation='relu',input_dim=number_inputs))
model.add(Dense(units=nodes_number, activation='relu'))
model.add(Dense(units=number_output, activation='softmax'))

# %% [markdown]
# # Train this Model

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_train_sc,y_train_cat, epochs=20,shuffle=True, verbose=2)
# Out:
# Epoch 1/20
#  - 0s - loss: 0.5691 - accuracy: 0.7006
# Epoch 2/20
#  - 0s - loss: 0.3648 - accuracy: 0.8123
# Epoch 3/20
#  - 0s - loss: 0.3451 - accuracy: 0.8295
# Epoch 4/20
#  - 0s - loss: 0.3369 - accuracy: 0.8287
# Epoch 5/20
#  - 0s - loss: 0.3288 - accuracy: 0.8346
# Epoch 6/20
#  - 0s - loss: 0.3336 - accuracy: 0.8350
# Epoch 7/20
#  - 0s - loss: 0.3259 - accuracy: 0.8423
# Epoch 8/20
#  - 0s - loss: 0.3191 - accuracy: 0.8444
# Epoch 9/20
#  - 0s - loss: 0.3122 - accuracy: 0.8516
# Epoch 10/20
#  - 0s - loss: 0.3069 - accuracy: 0.8550
# Epoch 11/20
#  - 0s - loss: 0.3036 - accuracy: 0.8617
# Epoch 12/20
#  - 0s - loss: 0.3010 - accuracy: 0.8629
# Epoch 13/20
#  - 0s - loss: 0.2982 - accuracy: 0.8657
# Epoch 14/20
#  - 0s - loss: 0.2912 - accuracy: 0.8692
# Epoch 15/20
#  - 0s - loss: 0.2959 - accuracy: 0.8669
# Epoch 16/20
#  - 0s - loss: 0.2940 - accuracy: 0.8657
# Epoch 17/20
#  - 0s - loss: 0.2927 - accuracy: 0.8638
# Epoch 18/20
#  - 0s - loss: 0.2816 - accuracy: 0.8756
# ...

# %%
model_loss, model_accuracy=model.evaluate(X_train_sc,y_train_cat, verbose=2)
print(model_loss)
print(model_accuracy)
# Out:
# 0.2712353457794966
# 0.8802212476730347

# %% [markdown]
# # Predictions

# %%
new_data=X_test_sc[:20]
new_data_y=y_test[:20]
pr=model.predict_classes(new_data)
res_coded=y_encoder.inverse_transform(pr)
result=pd.DataFrame({"actual":new_data_y,"predicted":res_coded})
result
# Out:
#               actual       predicted
# 4982  FALSE POSITIVE  FALSE POSITIVE
# 4866       CANDIDATE       CANDIDATE
# 2934  FALSE POSITIVE  FALSE POSITIVE
# 5007  FALSE POSITIVE  FALSE POSITIVE
# 3869  FALSE POSITIVE  FALSE POSITIVE
# 233        CONFIRMED       CONFIRMED
# 1554       CANDIDATE       CONFIRMED
# 6156       CANDIDATE       CANDIDATE
# 4874       CANDIDATE       CANDIDATE
# 4844  FALSE POSITIVE  FALSE POSITIVE
# 2471       CONFIRMED       CONFIRMED
# 2398       CONFIRMED       CONFIRMED
# 239        CONFIRMED       CONFIRMED
# 5681  FALSE POSITIVE  FALSE POSITIVE
# 4701       CANDIDATE       CANDIDATE
# 5706       CANDIDATE       CANDIDATE
# 3617  FALSE POSITIVE  FALSE POSITIVE
# 5982  FALSE POSITIVE  FALSE POSITIVE
# 1426       CONFIRMED       CONFIRMED
# 3614       CONFIRMED       CONFIRMED

# %%
#Save the Model
import joblib
filename = 'deep_model.sav'
joblib.dump(model, filename)
# Out:
# ['deep_model.sav']

# %% [markdown]
# # Support Vector Machine Model

# %%
from sklearn.svm import SVC
modelSVC=SVC(kernel='linear')
modelSVC.fit(X_train_sc,y_train_encod)
modelSVC.score(X_train_sc,y_train_encod)
# Out:
# 0.8455082967766546

# %%
pred=modelSVC.predict(X_test_sc)
from sklearn.metrics import classification_report
print (classification_report(y_test_encod,pred, target_names=['CANDIDATE','CONFIRMED','FALSE POSITIVE']))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.70      0.62      0.66       411
#      CONFIRMED       0.71      0.76      0.73       484
# FALSE POSITIVE       0.98      1.00      0.99       853
#
#       accuracy                           0.84      1748
#      macro avg       0.80      0.79      0.79      1748
#   weighted avg       0.84      0.84      0.84      1748

# %%
pred_cat=y_encoder.inverse_transform(pred)
table=pd.DataFrame({"Actual":y_test[:20],"Predicted":pred_cat[:20]})
table
# Out:
#               Actual       Predicted
# 4982  FALSE POSITIVE  FALSE POSITIVE
# 4866       CANDIDATE       CANDIDATE
# 2934  FALSE POSITIVE  FALSE POSITIVE
# 5007  FALSE POSITIVE  FALSE POSITIVE
# 3869  FALSE POSITIVE  FALSE POSITIVE
# 233        CONFIRMED       CONFIRMED
# 1554       CANDIDATE       CONFIRMED
# 6156       CANDIDATE       CANDIDATE
# 4874       CANDIDATE       CANDIDATE
# 4844  FALSE POSITIVE  FALSE POSITIVE
# 2471       CONFIRMED       CONFIRMED
# 2398       CONFIRMED       CONFIRMED
# 239        CONFIRMED       CONFIRMED
# 5681  FALSE POSITIVE  FALSE POSITIVE
# 4701       CANDIDATE       CANDIDATE
# 5706       CANDIDATE       CANDIDATE
# 3617  FALSE POSITIVE  FALSE POSITIVE
# 5982  FALSE POSITIVE  FALSE POSITIVE
# 1426       CONFIRMED       CONFIRMED
# 3614       CONFIRMED       CONFIRMED

# %%
#Save the Model
joblib.dump(modelSVC,"SVC_model.sav")
# Out:
# ['SVC_model.sav']

# %%
print(f"Training Data Score: {modelSVC.score(X_train_sc, y_train_encod)}")
print(f"Testing Data Score: {modelSVC.score(X_test_sc, y_test_encod)}")
# Out:
# Training Data Score: 0.8455082967766546
# Testing Data Score: 0.8415331807780321

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid={'C':[0.1,1,3,100], 'gamma':[0.0001, 0.0005, 0.001, 0.005]}
grid=GridSearchCV(modelSVC, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_sc,y_train_encod)
#grid.estimator.get_params().keys()
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] C=0.1, gamma=0.0001 .............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................. C=0.1, gamma=0.0001, score=0.841, total=   0.3s
# [CV] C=0.1, gamma=0.0001 .............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [CV] ................. C=0.1, gamma=0.0001, score=0.829, total=   0.3s
# [CV] C=0.1, gamma=0.0001 .............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.6s remaining:    0.0s
# [CV] ................. C=0.1, gamma=0.0001, score=0.835, total=   0.3s
# [CV] C=0.1, gamma=0.0001 .............................................
# [CV] ................. C=0.1, gamma=0.0001, score=0.812, total=   0.3s
# [CV] C=0.1, gamma=0.0001 .............................................
# ...

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 100, 'gamma': 0.0001}
# 0.8859393533645274

# %%
pr11=grid.predict(X_test_sc)
pr11_cat=y_encoder.inverse_transform(pr11)
SVC_grig_df=pd.DataFrame({"Actual":y_test[:20],"Predicted":pr11_cat[:20]})
SVC_grig_df
# Out:
#               Actual       Predicted
# 4982  FALSE POSITIVE  FALSE POSITIVE
# 4866       CANDIDATE       CANDIDATE
# 2934  FALSE POSITIVE  FALSE POSITIVE
# 5007  FALSE POSITIVE  FALSE POSITIVE
# 3869  FALSE POSITIVE  FALSE POSITIVE
# 233        CONFIRMED       CONFIRMED
# 1554       CANDIDATE       CONFIRMED
# 6156       CANDIDATE       CANDIDATE
# 4874       CANDIDATE       CANDIDATE
# 4844  FALSE POSITIVE  FALSE POSITIVE
# 2471       CONFIRMED       CONFIRMED
# 2398       CONFIRMED       CONFIRMED
# 239        CONFIRMED       CONFIRMED
# 5681  FALSE POSITIVE  FALSE POSITIVE
# 4701       CANDIDATE       CANDIDATE
# 5706       CANDIDATE       CANDIDATE
# 3617  FALSE POSITIVE  FALSE POSITIVE
# 5982  FALSE POSITIVE  FALSE POSITIVE
# 1426       CONFIRMED       CONFIRMED
# 3614       CONFIRMED       CANDIDATE

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/
joblib.dump(grid, 'grid.sav')
# Out:
# ['grid.sav']

# %%
pr=grid.predict(X_test_sc)
print(classification_report(y_test_encod,pr, target_names=['CANDIDATE','CONFIRMED','FALSE POSITIVE']))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.80      0.68      0.74       411
#      CONFIRMED       0.77      0.84      0.80       484
# FALSE POSITIVE       0.98      1.00      0.99       853
#
#       accuracy                           0.88      1748
#      macro avg       0.85      0.84      0.84      1748
#   weighted avg       0.88      0.88      0.88      1748

# %% [markdown]
# # KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier
test_scores=[]
train_scores=[]
for k in range(10,80,5):
    knn=KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_sc,y_train_encod)
    train_score=knn.score(X_train_sc,y_train_encod)
    train_scores.append(train_score)
    test_score=knn.score(X_test_sc,y_test_encod)
    test_scores.append(test_score)
    print(f"k:{k} train_score: {train_score} test_score: {test_score}")
# Out:
# k:10 train_score: 0.8577150486362769 test_score: 0.8255148741418764
# k:15 train_score: 0.8409307648292962 test_score: 0.8243707093821511
# k:20 train_score: 0.8416936868205226 test_score: 0.8272311212814645
# k:25 train_score: 0.8369254243753577 test_score: 0.8237986270022883
# k:30 train_score: 0.8376883463665841 test_score: 0.8237986270022883
# k:35 train_score: 0.8331108144192256 test_score: 0.8255148741418764
# k:40 train_score: 0.834827388899485 test_score: 0.8243707093821511
# k:45 train_score: 0.8281518214762541 test_score: 0.8243707093821511
# k:50 train_score: 0.83005912645432 test_score: 0.8255148741418764
# k:55 train_score: 0.8283425519740607 test_score: 0.8209382151029748
# k:60 train_score: 0.8292962044630936 test_score: 0.8255148741418764
# k:65 train_score: 0.8252908640091551 test_score: 0.8220823798627003
# k:70 train_score: 0.8258630555025749 test_score: 0.8197940503432495
# k:75 train_score: 0.8245279420179287 test_score: 0.816933638443936

# %%
import matplotlib.pyplot as plt
plt.plot(range(10,80,5), train_scores, marker='*', color='red')
plt.plot(range(10,80,5), test_scores, marker='x', color='blue')
plt.show()

# %%
# k=20 => after that situation became more or less stable for a short time
modelKNN=KNeighborsClassifier(n_neighbors=25)
modelKNN.fit(X_train_sc,y_train_encod)
modelKNN.score(X_train_sc,y_train_encod)
#TakeAway- weak model
# Out:
# 0.8369254243753577

# %%
pr2=modelKNN.predict(X_test_sc)
pr2_cat=y_encoder.inverse_transform(pr2)
KNNdf=pd.DataFrame({"Actual":y_test[:20],"Predicted":pr2_cat[:20]})
KNNdf
# Out:
#               Actual       Predicted
# 4982  FALSE POSITIVE  FALSE POSITIVE
# 4866       CANDIDATE       CONFIRMED
# 2934  FALSE POSITIVE  FALSE POSITIVE
# 5007  FALSE POSITIVE  FALSE POSITIVE
# 3869  FALSE POSITIVE  FALSE POSITIVE
# 233        CONFIRMED       CONFIRMED
# 1554       CANDIDATE       CONFIRMED
# 6156       CANDIDATE       CONFIRMED
# 4874       CANDIDATE       CANDIDATE
# 4844  FALSE POSITIVE  FALSE POSITIVE
# 2471       CONFIRMED       CONFIRMED
# 2398       CONFIRMED       CONFIRMED
# 239        CONFIRMED       CONFIRMED
# 5681  FALSE POSITIVE  FALSE POSITIVE
# 4701       CANDIDATE       CANDIDATE
# 5706       CANDIDATE       CANDIDATE
# 3617  FALSE POSITIVE  FALSE POSITIVE
# 5982  FALSE POSITIVE  FALSE POSITIVE
# 1426       CONFIRMED       CONFIRMED
# 3614       CONFIRMED       CONFIRMED

# %%
joblib.dump(modelKNN,'KNN.sav')
# Out:
# ['KNN.sav']

# %%
pr=modelKNN.predict(X_test_sc)
print(classification_report(y_test_encod,pr, target_names=['CANDIDATE','CONFIRMED','FALSE POSITIVE']))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.69      0.50      0.58       411
#      CONFIRMED       0.66      0.79      0.72       484
# FALSE POSITIVE       0.98      1.00      0.99       853
#
#       accuracy                           0.82      1748
#      macro avg       0.78      0.76      0.76      1748
#   weighted avg       0.82      0.82      0.82      1748
